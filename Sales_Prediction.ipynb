# %%
import pandas as pd
import numpy as np



df=  pd.read_csv("sales.csv")

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
print(df.isnull().sum())
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# <p style="color:blue">no null values</p>

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <h2> visualize correlation between sales and avertiesement meida </h2>

# %%
import seaborn as sns

sns.regplot(x='Sales' ,y='TV' , data=df)

# %%
sns.regplot(x='Sales' ,y='Radio' , data=df)

# %%
sns.regplot(x='Sales' ,y='Newspaper' , data=df)

# %%
#manually calculate the degreee of correlation
correlation = df.corr()
print(correlation["Sales"].sort_values(ascending=False))
# Out:
# Sales        1.000000
# TV           0.901208
# Radio        0.349631
# Newspaper    0.157960
# Name: Sales, dtype: float64

# %% [markdown]
# <p> strongest relation is between advertising in TV and Salse</p>

# %% [markdown]
# <h1>Prediction Model Development</h1>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

x = np.array(df.drop(columns=['Sales']))
y = np.array(df["Sales"])
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)
model = LinearRegression()
model.fit(xtrain, ytrain)
print(model.score(xtest, ytest))

      
      
# features = [[TV, Radio, Newspaper]]
features = np.array([[230.1, 45.8, 69.2]])
yhat = model.predict(features)

yhat
# print(model.predict(x))
# Out:
# 0.9059011844150826
# array([22.18010318])
